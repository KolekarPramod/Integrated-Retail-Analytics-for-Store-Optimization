# %% [markdown]
# <a href="https://colab.research.google.com/github/KolekarPramod/Integrated-Retail-Analytics-for-Store-Optimization/blob/main/Integrated_Retail_Analytics_for_Store_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# # Project Objective:
# To utilize machine learning and data analysis techniques to optimize store performance, forecast demand, and enhance customer experience through segmentation and personalized marketing strategies.

# %% [markdown]
# # Project Components:
#
# * **Anomaly Detection in Sales Data:**
#   Identify unusual sales patterns across stores and departments.
#   Investigate potential causes (e.g., holidays, markdowns, economic indicators).
#   Implement anomaly handling strategies to clean the data for further analysis.
#
# * **Time-Based Anomaly Detection:**
#   Analyze sales trends over time.
#   Detect seasonal variations and holiday effects on sales.
#   Use time-series analysis for understanding store and department performance over time.
#
# * **Data Preprocessing and Feature Engineering:**
#   Handle missing values, especially in the MarkDown data.
#   Create new features that could influence sales (e.g., store size/type, regional factors).
#
# * **Customer Segmentation Analysis:**
#   Segment stores or departments based on sales patterns, markdowns, and regional features.
#   Analyze segment-specific trends and characteristics.
#
# * **Market Basket Analysis:**
#   Although individual customer transaction data is not available, infer potential product associations within departments using sales data.
#   Develop cross-selling strategies based on these inferences.
#
# * **Demand Forecasting:**
#   Build models to forecast weekly sales for each store and department.
#   Incorporate factors like CPI, unemployment rate, fuel prices, and store/dept attributes.
#   Explore short-term and long-term forecasting models.
#
# * **Impact of External Factors:**
#   Examine how external factors (economic indicators, regional climate) influence sales.
#   Incorporate these insights into the demand forecasting models.
#
# * **Personalization Strategies:**
#   Develop personalized marketing strategies based on the markdowns and store segments.
#   Propose inventory management strategies tailored to store and department needs.
#
# * **Segmentation Quality Evaluation:**
#   Evaluate the effectiveness of the customer segmentation.
#   Use metrics to assess the quality of segments in terms of homogeneity and separation.
#
# * **Real-World Application and Strategy Formulation:**
#   Formulate a comprehensive strategy for inventory management, marketing, and store optimization based on the insights gathered.
#   Discuss potential real-world challenges in implementing these strategies.

# %% [markdown]
# # Data Preprocessing and Visualization.
# Statistical Analysis.
# Deliverables:
# A detailed report with analysis, insights, and strategic recommendations.
# Predictive models for sales forecasting and anomaly detection.
# Segmentation analysis and market basket insights.
# Code and data visualizations to support findings.

# %% [markdown]
# # Tools and Techniques:
# Machine Learning (e.g., clustering, time-series forecasting models, association rules).

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/KolekarPramod/Integrated-Retail-Analytics-for-Store-Optimization

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Dataset Loading
url= 'https://drive.google.com/file/d/1dkwBc9UTbzAAjGwJZ1egEwxjKCzonszj/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
features_df = pd.read_csv(url)

# %%
url= 'https://drive.google.com/file/d/1qYM7iZHDQWtTT5OajLHCEG8qvSpZbwIr/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
sales_df = pd.read_csv(url)

# %%
url= 'https://drive.google.com/file/d/1mMsJkQNFRO30adycSj2R7tfQ1FKpGK1O/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
stores_df = pd.read_csv(url)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
features_df.head()

# %%
sales_df.head()

# %%
stores_df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
features_df.shape

# %%
sales_df.shape

# %%
stores_df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
features_df.info()

# %%
sales_df.info()

# %%
stores_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print('Number of Duplicated values in feature dataframe:',features_df.duplicated().sum())
print('Number of Duplicated values in sales dataframe  :',sales_df.duplicated().sum())
print('Number of Duplicated values in stores dataframe :',stores_df.duplicated().sum())

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
features_df.isnull().sum()/features_df.shape[0]*100

# %%
sales_df.isnull().sum()/sales_df.shape[0]*100

# %%
stores_df.isnull().sum()/stores_df.shape[0]*100

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * Feature Dataframe contains Null values in all Markdown columns almost more than 50%
#
# * No Duplicates values found in all three dataframe
#
# * No Null values found in stores and sales dataframe

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(features_df.columns)

# %%
sales_df.columns

# %%
stores_df.columns

# %%
# Dataset Describe
features_df.describe()

# %%
sales_df.describe()

# %%
stores_df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ## **About Dataset**
#
#
# ##**Stores**
# * Anonymized information about the 45 stores, indicating the type and size of store
#
# ##**Features**
#
# $\color{yellow}{\text{Features}}$ – Contains additional contextual and regional data aligned with each store and date, providing signals influencing sales patterns.
#
# $\color{yellow}{\text{Store}}$ – The unique identifier for each store location.
#
# $\color{yellow}{\text{Date}}$ – The specific week being referenced.
#
# $\color{yellow}{\text{Temperature}}$ – Average ambient temperature in the region during the week, reflecting weather conditions.
#
# $\color{yellow}{\text{Fuel_Price}}$ – The price per gallon of fuel in the region during that week, indicating local economic conditions.
#
# $\color{yellow}{\text{MarkDown1-5}}$ – Different phases of permanent price reductions applied to products, from initial small discounts to deep clearance markdowns.
#
# $\color{yellow}{\text{CPI}}$ – Consumer Price Index, indicating the general price level for consumer goods in the region.
#
# $\color{yellow}{\text{Unemployment}}$ – Unemployment rate within the region, providing a measure of economic health.
#
# $\color{yellow}{\text{IsHoliday}}$ – Indicates whether the week contains a special holiday, with True for holiday weeks and False otherwise.
#
#
#
#
# ##**Sales**
#
# $\color{yellow}{\text{Sales}}$ – Historical sales transactions spanning from 2010-02-05 to 2012-11-01, capturing store and department-level weekly sales.
#
# $\color{yellow}{\text{Store}}$ – The store number where the sales were recorded.
#
# $\color{yellow}{\text{Dept}}$ – The department number within the store, indicating product category.
#
# $\color{yellow}{\text{Date}}$ – The specific week when the sales occured.
#
# $\color{yellow}{\text{Weekly_Sales}}$ – Total sales revenue for the given department in the specified store for that week.
#
# $\color{yellow}{\text{IsHoliday}}$ – Indicates whether the week was a special holiday week, which often affects sales volume and patterns.

# %% [markdown]
# # What Do MarkDown1 to MarkDown5 Represent?

# %% [markdown]
# In the retail industry, a markdown refers to a permanent reduction in the original selling price of a product. This is done to increase the product’s attractiveness to customers and stimulate sales, especially when:
#  The product is not selling well at its original price.
#  Seasonal items need to be cleared out.
#  The store wants to make room for new inventory.
#  The item is damaged or obsolete.
#
# These likely represent different types or phases of markdowns applied to products in a retail setting. Here's a likely interpretation based on standard retail practices:
# ColumnMeaning (Likely)
#
# 1. MarkDown1: Initial or minor discount – e.g., 10–20% off
# 2. MarkDown2: Follow-up reduction for low-performing items
# 3. MarkDown3: Further markdown – more aggressive, e.g., 30%+
# 4. MarkDown4: Clearance-level markdowns
# 5. MarkDown5: Final or deep clearance discount (e.g., 50%+)
#
#
#
# ###Why Are There Many Null Values?
#  Not all products go through all markdown phases.
#  Some weeks or stores may not apply certain markdowns.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in list(features_df.columns):
  print(f'Uniqe values in----> {i} {features_df[i].unique()}')
  print()

# %%
# Check Unique Values for each variable.
for i in list(sales_df.columns):
  print(f'Uniqe values in----> {i} {sales_df[i].unique()}')
  print()

# %%
# Check Unique Values for each variable.
for i in list(stores_df.columns):
  print(f'Uniqe values in----> {i} {stores_df[i].unique()}')
  print()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
features_df['Date'] = pd.to_datetime(features_df['Date'],dayfirst=True)
sales_df['Date'] = pd.to_datetime(sales_df['Date'],dayfirst=True)

# %%
features_df.info()

# %% [markdown]
# # Merging the Data

# %%
# Merge different datasets
df = pd.merge(sales_df, features_df, how = 'left', on = ['Store','Date','IsHoliday']) # merging sales and features by left since there are more rows for sales
final_df = pd.merge(df, stores_df, how = 'left', on = 'Store') #merge df and df_stores by left to keep all the columns and rows

# %%
#Check for missing values
final_df.isnull().sum()

# %%
# Set your DataFrame name
markdown_cols = ['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5']

plt.figure(figsize=(20, 10))

for i, col in enumerate(markdown_cols, 1):
    plt.subplot(2, 3, i)
    # Histogram ignoring NaNs
    sns.histplot(final_df[col].dropna(), bins=50, kde=True, color='skyblue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

    # Compute and display mean/median/skew
    mean_val = final_df[col].mean()
    median_val = final_df[col].median()
    skew_val = final_df[col].skew()

    plt.axvline(mean_val, color='red', linestyle='dashed', linewidth=1, label=f"Mean: {mean_val:.2f}")
    plt.axvline(median_val, color='green', linestyle='dashed', linewidth=1, label=f"Median: {median_val:.2f}")
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Console output for skewness and null count
for col in markdown_cols:
    mean_val = final_df[col].mean()
    median_val = final_df[col].median()
    skew_val = final_df[col].skew()
    null_count = final_df[col].isna().sum()
    print(f"{col}: Skewness={skew_val:.3f} | Mean={mean_val:.2f} | Median={median_val:.2f} | Nulls={null_count}")

# %%
final_df = final_df.fillna(0)

# %%
# Console output for skewness and null count
for col in markdown_cols:
    mean_val = final_df[col].mean()
    median_val = final_df[col].median()
    skew_val = final_df[col].skew()
    null_count = final_df[col].isna().sum()
    print(f"{col}: Skewness={skew_val:.3f} | Mean={mean_val:.2f} | Median={median_val:.2f} | Nulls={null_count}")

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Converted All Date columns into proper datetime format
# 2. Joined the all table on the basis of Store
# 3. Fill the Null Values of markdown with 0 since there no discount was given

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
features_df

# %%
# Chart - 1 visualization code

plt.figure(figsize=(12,6))
sns.lineplot(x='Date', y = 'Weekly_Sales', data= sales_df)
plt.xticks(rotation = 25)
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows clear seasonal spikes in weekly sales around the end of each year, indicating strong holiday season effects, with overall weekly sales remaining stable but slightly fluctuating throughout the years.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Calculate the value counts for 'IsHoliday'
holiday_counts = sales_df['IsHoliday'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(holiday_counts, autopct='%1.1f%%', labels=holiday_counts.index, startangle=90)
plt.title('Distribution of Holidays')
plt.legend()
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# Only **7% of the weeks are holiday weeks** in the dataset, indicating holiday effects occur in a small but impactful portion of the sales period.
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sales_df

# %%
df =sales_df.set_index('Date')

# %%
df

# %%
df.info()

# %%
store_1 = df[df['Store']==1]

# %%
store_1

# %%
store_1.info()

# %%
sales_df

# %%
sales_df[(sales_df['Date']=='2010-02-05') & (sales_df['Store']== 1)]

# %%
store_1.drop(columns='Store',inplace=True)

# %%
import matplotlib.pyplot as plt

# Step 1: Group by Store and Date, summing sales across departments
df_grouped = df.groupby(['Store', df.index]).sum()

# Step 2: Loop through each Store and plot its sales over time
stores = df_grouped.index.get_level_values('Store').unique()

for store_id in stores:
    store_sales = df_grouped.loc[store_id]
    plt.figure(figsize=(12, 6))
    plt.plot(store_sales.index, store_sales['Weekly_Sales'], label=f'Store {store_id}')
    plt.title(f'Store {store_id} - Weekly Sales Over Time')
    plt.xlabel('Date')
    plt.ylabel('Total Weekly Sales')
    plt.grid(True)
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
cpi_across_time = final_df.groupby(by = ['Date'], as_index= False)['CPI'].mean()
plt.figure(figsize = (25,5))
plt.plot(cpi_across_time.Date, cpi_across_time.CPI, color="y")
plt.xlabel('Date')
plt.ylabel("Average CPI")
plt.title("Average CPI across time")
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **Average CPI shows a clear upward trend over time**, indicating consistent inflation across the dataset period.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
fuel_across_time = final_df.groupby(by = ['Date'], as_index= False)['Fuel_Price'].mean()
plt.figure(figsize=(25,5))
plt.plot(fuel_across_time.Date, fuel_across_time.Fuel_Price, color="g")
plt.xlabel('Date')
plt.ylabel('Average Fuel Price')
plt.title("Average Fuel Price across time")
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **average fuel price shows cyclical fluctuations with clear peaks and drops**, indicating volatility in fuel prices over the analyzed period.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
temp_across_time = final_df.groupby(by = ['Date'], as_index= False)['Temperature'].mean()
plt.figure(figsize=(25,5))
plt.plot(temp_across_time.Date, temp_across_time.Temperature, color="r")
plt.xlabel('Date')
plt.ylabel('Average Temperature')
plt.title("Average Temperature across time")
plt.show()

# %% [markdown]
# ##### . What is/are the insight(s) found from the chart?

# %% [markdown]
# The **average temperature displays a clear seasonal cycle**, peaking in mid-year and dropping at year-end consistently across all years.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
df_markdown = final_df.groupby('Date').agg({'MarkDown1': 'mean', 'MarkDown2': 'mean', 'MarkDown3': 'mean', 'MarkDown4': 'mean', 'MarkDown5': 'mean'})
plt.figure(figsize = (30,10))

plt.plot(df_markdown.index, df_markdown.MarkDown1, label = 'MarkDown1')
plt.plot(df_markdown.index, df_markdown.MarkDown2, label = 'MarkDown2')
plt.plot(df_markdown.index, df_markdown.MarkDown3, label = 'MarkDown3')
plt.plot(df_markdown.index, df_markdown.MarkDown4, label = 'MarkDown4')
plt.plot(df_markdown.index, df_markdown.MarkDown5, label = 'MarkDown5')


plt.xlabel("Date")
plt.ylabel("Average Markdown ($)")
plt.title("Average Markdown across Time")
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# Markdown activity **starts appearing around late 2011 with sharp spikes and fluctuations**, indicating markdown strategies were implemented heavily only in the later period of the dataset.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
df_markdown_month = final_df.groupby(final_df.Date.dt.month).agg({'MarkDown1': 'mean', 'MarkDown2': 'mean', 'MarkDown3': 'mean', 'MarkDown4': 'mean', 'MarkDown5': 'mean'})
df_markdown_month.head()
df_markdown_month.plot(kind = 'bar', figsize = (20,10), rot = 0)
plt.xlabel("Months")
plt.ylabel('Average Markdown')
plt.title('Average Markdown per Month')
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# Markdown amounts **peak strongly in November and February**, indicating **heavy markdown activity around holiday and clearance periods** during these months.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
df_markdown_type = final_df.groupby(final_df.Type).agg({'MarkDown1': 'mean', 'MarkDown2': 'mean', 'MarkDown3': 'mean', 'MarkDown4': 'mean', 'MarkDown5': 'mean'})
df_markdown_type.head()
df_markdown_type.plot(kind = 'bar', figsize = (10,10), rot = 0)
plt.xlabel("Type")
plt.ylabel('Average Markdown')
plt.title('Average Markdown per Type')
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Type A stores have the highest markdown averages across all categories, followed by Type B, with Type C having minimal markdown activity,** indicating markdown strategies are primarily used in larger store types.

# %% [markdown]
# #### Chart - 10

# %%
df

# %%
# plt.figure(figsize = (16,6))

# final_df = df.astype(float, errors = 'ignore')
# heatmap = sns.heatmap(final_df.corr(), vmin = -1, vmax = 1, annot = True, cmap = 'BrBG')
# heatmap.set_title('Correlation heatmap', fontdict = {'fontsize':18}, pad=12);

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# **There is a weak positive correlation (0.15) between Dept and Weekly_Sales, with all other variables showing negligible correlations, indicating low linear dependency in this subset.**

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
final_df.info()

# %%
# Pair Plot visualization code
numeric_cols = final_df.select_dtypes(include=['float', 'int']).columns

# Plot pair plot
sns.pairplot(final_df[numeric_cols], diag_kind='kde', corner=True)
plt.suptitle("Pair Plot of Numeric Features", fontsize=16, y=1.02)
plt.show()

# %% [markdown]
# ##### 1. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. `Fuel_Price` and `CPI` are near-normal with slight right skew.
# 2. `MarkDown` columns are **positively correlated with each other**.
# 3. `MarkDown1` and `MarkDown4` show **weak positive relation with `Weekly_Sales`**.
# 4. `Weekly_Sales` has **no strong correlation with `Fuel_Price`, `CPI`, or `Unemployment`**.
# 5. `CPI` and `Fuel_Price` show **mild positive correlation**.
# 6. `Unemployment` has **slight negative correlation with `CPI`**.
# 7. Many **outliers and clusters** are visible, indicating potential need for further cleaning or segmentation.
# 8. **Overall, no strong linear relationships** dominate, suggesting feature engineering may be needed for modeling.

# %% [markdown]
# ## 🚨 **Anomaly Detection in Sales Data**
#
# * Spot unusual sales patterns across stores and departments.
# * Check possible reasons (holidays, markdowns, economic changes).
# * Handle anomalies to prepare clean data for analysis.
#
# ## 🛠️ Mitigation Strategies
#
# ✨ **Data Cleaning:** Find and fix errors in the data manually or with automated tools.
#
# ✨ **Data Normalization:** Transform data to a normal distribution to make anomalies easier to detect.
#
# ✨ **Data Imputation:** Fill missing values using statistical or machine learning methods to maintain data quality.

# %% [markdown]
# ### 📊 **Descriptive Statistics**
#
# Descriptive statistics are basic tools for spotting anomalies in retail data.
#
# Using **mean, median, and standard deviation**, you can calculate summary stats to help identify unusual data points easily.

# %%
# Step 2: Normalize Sales Data (Standardization)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Reshape the column to a 2D array and apply min-max scaling
final_df['Weekly_Sales_normalized'] = scaler.fit_transform(final_df['Weekly_Sales'].values.reshape(-1, 1))

# %%
final_df['Sales_sqrt'] = final_df['Weekly_Sales_normalized'].apply(lambda x: x ** 0.5)

# %%
import numpy as np

# Calculate mean and standard deviation
mean_sales = np.mean(final_df['Sales_sqrt'])
std_deviation = np.std(final_df['Sales_sqrt'])

# Set a threshold for flagging anomalies (e.g., 3 standard deviations from the mean)
threshold = mean_sales + 3 * std_deviation

# Identify anomalies
anomalies = [data_point for data_point in final_df['Sales_sqrt'] if data_point > threshold]

#If the data point exceeds the threshold, it assigns a value of 1 (indicating an anomaly), otherwise it assigns a value of 0.
final_df['Anomaly'] = [1 if data_point > threshold else 0 for data_point in final_df['Sales_sqrt']]

print("Retail Weekly Sales Data:")
print("Mean Sales:", mean_sales)
print("Standard Deviation:", std_deviation)
print("Anomalies (2 standard deviations from the mean)-Total number of Anomalies in Weekly Sales :", len(anomalies))
print("Total number of Anomalies in Weekly Sales (percentage-wise) :", round((len(anomalies)/len(sales_df))*100,2))

# %%
final_df['Anomaly'].value_counts()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the features and plot types
features = {
  'Size': 'scatter',
  'CPI': 'scatter',
  'Unemployment': 'scatter',
  'Fuel_Price': 'scatter',
  'Temperature': 'scatter',
  'Date': 'line',
}

# Calculate number of rows and columns
num_features = len(features)
ncols = 2
nrows = (num_features + ncols - 1) // ncols  # Ensure enough rows

# Set up subplots with 2 graphs per row
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, nrows * 10))
axes = axes.flatten()

# Iterate over each feature and plot accordingly
for i, (feature, plot_type) in enumerate(features.items()):
    if plot_type == 'scatter':
        sns.scatterplot(x=feature, y='Sales_sqrt', hue='Anomaly', data=final_df, ax=axes[i])
    elif plot_type == 'line':
        sns.lineplot(x=feature, y='Sales_sqrt', hue='Anomaly', data=final_df, ax=axes[i])
    elif plot_type == 'bar':
        sns.barplot(x=feature, y='Sales_sqrt', hue='Anomaly', data=final_df, ax=axes[i])

    axes[i].set_title(f'{feature}-wise Weekly Sales Anomalies')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Weekly Sales')

    # Optional: Add data labels to bar plots
    if plot_type == 'bar':
        for p in axes[i].patches:
            axes[i].annotate(format(p.get_height(), '.2f'),
                             (p.get_x() + p.get_width() / 2., p.get_height()),
                             ha='center', va='center',
                             xytext=(0, 10),
                             textcoords='offset points')

# Remove any empty subplots
for j in range(len(features), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### **Findings on Anomalies**
#
# 1. **Holidays Boost Sales:** Sales are higher during holidays, while 90% of regular days show lower sales.
# 2. **Seasonal Consumer Behavior:** Sales rise due to festive spending, discounts, and promotions.
# 3. **Business Strategies:** Businesses run promotions and campaigns during holidays, driving up sales.
# 4. **Anomaly Patterns:** Sales are more variable and less predictable during holidays, making anomaly detection crucial.
# 5. **Actionable Insight:** Including holidays and seasonality in forecasting and marketing helps maximize sales and growth.

# %%
print("Skewness - Cost: %f" % final_df['Weekly_Sales'].skew())
print("Kurtosis - Cost: %f" % final_df['Weekly_Sales'].kurt())

# %%
#isolation forest for anamoly detection on Weekly Sales
from sklearn.ensemble import IsolationForest

isolation_forest = IsolationForest(n_estimators=100, contamination=0.01)
isolation_forest.fit(final_df['Weekly_Sales'].values.reshape(-1, 1))
final_df['anomaly_score_univariate_Weekly_Sales'] = isolation_forest.decision_function(final_df['Weekly_Sales'].values.reshape(-1, 1))
final_df['outlier_univariate_Weekly_Sales'] = isolation_forest.predict(final_df['Weekly_Sales'].values.reshape(-1, 1))

# %%
#chart to visualize outliers
xx = np.linspace(final_df['Weekly_Sales'].min(), final_df['Weekly_Sales'].max(), len(final_df)).reshape(-1,1)
anomaly_score = isolation_forest.decision_function(xx)
outlier = isolation_forest.predict(xx)
plt.figure(figsize=(10,4))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score),
where=outlier==-1, color='r',
alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Weekly Sales')
plt.show();

# %% [markdown]
# Weekly Sales below approximately $120,000 are considered normal, while higher values are increasingly flagged as anomalies by the Isolation Forest model because such high sales are rare in the dataset and deviate from the learned pattern of typical behavior.

# %%
# Handling Outliers & Outlier treatments
# To separate the symmetric distributed features and skew symmetric distributed features
num_columns=['Weekly_Sales', 'Size', 'Temperature',
       'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4',
       'MarkDown5', 'CPI', 'Unemployment']
symmetric_feature=[]
non_symmetric_feature=[]
for i in num_columns:
  if abs(final_df[i].mean()-final_df[i].median())< 0.2:
    symmetric_feature.append(i)
  else:
    non_symmetric_feature.append(i)

# Getting Symmetric Distributed Features
print("Symmetric Distributed Features : -",symmetric_feature)

# Getting Skew Symmetric Distributed Features
print("Skew Symmetric Distributed Features : -",non_symmetric_feature)

# %%
# For Skew Symmetric features defining upper and lower boundry
#Outer Fence
def outlier_treatment_skew(df,feature):
  IQR= df[feature].quantile(0.75)- df[feature].quantile(0.25)
  lower_bridge =df[feature].quantile(0.25)- 1.5*IQR
  upper_bridge =df[feature].quantile(0.75)+ 1.5*IQR
  # print(f'upper : {upper_bridge} lower : {lower_bridge}')
  return upper_bridge,lower_bridge


# Get the upper and lower boundaries for 'Weekly_Sales'
upper_boundary, lower_boundary = outlier_treatment_skew(final_df, 'Weekly_Sales')
upper_boundary, lower_boundary

# %%
#Removing Anomalies using IQR
final_new_df=final_df[(final_df['Weekly_Sales'] >= lower_boundary) & (final_df['Weekly_Sales'] <= upper_boundary)]

#dropping the columns created while outliers treatment
final_new_df =final_new_df.drop(columns =['anomaly_score_univariate_Weekly_Sales','outlier_univariate_Weekly_Sales'])

# %%
# Calculate mean and standard deviation
mean_sales = np.mean(final_new_df['Sales_sqrt'])
std_deviation = np.std(final_new_df['Sales_sqrt'])

# Set a threshold for flagging anomalies (e.g., 3 standard deviations from the mean)
threshold = mean_sales + 3 * std_deviation

# Identify anomalies
anomalies = [data_point for data_point in final_new_df['Sales_sqrt'] if data_point > threshold]

#If the data point exceeds the threshold, it assigns a value of 1 (indicating an anomaly), otherwise it assigns a value of 0.
final_df['Anomaly'] = [1 if data_point > threshold else 0 for data_point in final_df['Sales_sqrt']]

print("Retail Weekly Sales Data:")
print("Mean Sales:", mean_sales)
print("Standard Deviation:", std_deviation)
print("Anomalies (2 standard deviations from the mean)-Total number of Anomalies in Weekly Sales :", len(anomalies))
print("Total number of Anomalies in Weekly Sales (percentage-wise) :", round((len(anomalies)/len(sales_df))*100,2))

# %% [markdown]
# # 🚦 **Time-Based Anomaly Detection **
#
# * Analyze sales patterns over time.
# * Identify seasonal and holiday impacts on sales.
# * Track store and department performance over time.
# * Detect unusual spikes or drops in sales data.
#
# ✨ **How to do it:**
#
# 🌀 **Rolling Stats:** Calculate moving averages and standard deviations to monitor sales changes.
#
# 📈 **Smooth Trends:** Use exponential moving averages to reveal underlying trends and spot unusual changes.
#
# 🔍 **Detect Anomalies:** Set clear thresholds to flag when sales are unusually high or low for quick detection of trends and issues.

# %% [markdown]
# ###**Rolling Statistics**
#
# Rolling statistics are a data analysis tool that can be used to identify outliers and trends in sequential and time-series data. They work by continuously recalculating statistical measures over a rolling window, which can help uncover anomalies and deviations that might not be obvious using traditional methods.

# %%
# Sort the DataFrame by date
final_df.sort_values(by='Date', inplace=True)

# %%
# Calculate rolling statistics
rolling_window = 30
# Rolling average of TotalSales
final_df['RollingAvgTotalSales'] = final_df['Weekly_Sales'].rolling(window=rolling_window).mean()

# Set anomaly threshold (customize this threshold as needed)
sales_threshold = 1  # Adjust the threshold as needed

# Detect anomalies in WeeklySales
final_df['SalesAnomaly'] = final_df['Weekly_Sales'] < sales_threshold * final_df['RollingAvgTotalSales']

# %%
# Visualize rolling statistics with original values and anomalies

plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Weekly_Sales', data=final_df, label='Weekly Sales')
sns.lineplot(x='Date', y='RollingAvgTotalSales', data=final_df, label='Rolling Avg Weekly Sales')
sns.lineplot(x='Date', y='Weekly_Sales', data=final_df[final_df['SalesAnomaly']], c='green', label='Sales Anomalies')

plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.title('Rolling Statistics with Anomalies for Sales Data')
plt.show()

# %% [markdown]
# **Observations:**
# * The graph shows the rolling statistics with anomalies for sales data.
# * The rolling average of sales does not show steadily increasing or decreasing over time, indicating that overall sales are trending constant.
# * There are a few anomalies in the sales data, as indicated by the green dots on the graph. These anomalies could be caused by a variety of factors, such as markdown events, seasonal fluctuations, or holidays.

# %%
final_df.info()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
